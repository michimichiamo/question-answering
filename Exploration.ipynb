# %%
from transformers import T5ForConditionalGeneration

# %%
from transformers import T5TokenizerFast

# %%
tokenizer = T5TokenizerFast.from_pretrained('t5-small')
# Out:
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]

# %%
model = T5ForConditionalGeneration.from_pretrained('/Users/micheleiannello/model/')

# %%
from util.model import read_npz
val_ids, val_contexts, val_attention_masks, val_questions = read_npz(path='./data/tokenized-qg/', split='val', task='QG')

# %%
# Importing libraries
import os
import numpy as np
import pandas as pd
import torch

# %%
class Dataset(torch.utils.data.Dataset):
    'Characterizes a dataset for PyTorch'
    def __init__(self, ids, contexts, attention_masks, questions):
        'Initialization'
        self.ids = ids
        self.contexts = contexts
        self.attention_masks = attention_masks
        self.questions = questions

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.contexts)

    def __getitem__(self, index):
        'Generates one sample of data'
        # Select sample
        ID = self.ids[index]
        context = torch.tensor(self.contexts[index], dtype=torch.int32)
        attention_mask = torch.tensor(self.attention_masks[index], dtype=torch.int32)
        question = torch.tensor(self.questions[index], dtype=torch.int32)

        # Pack input and output
        X = (ID, context, attention_mask)
        y = question

        return X, y

# %%
val_dataset = Dataset(val_ids[20:24], val_contexts[20:24], val_attention_masks[20:24], val_questions[20:24])

# %%
val_params = {
        'batch_size': 4,
        'shuffle': False,
        'num_workers': 0,
        'pin_memory' : True
        }
val_loader = torch.utils.data.DataLoader(val_dataset, **val_params)

# %%
device = 'cpu'

# %%
for X, Y in val_loader:
    # Unpack input
    _, context, attention_mask = X
    
    question = Y.to(device, dtype = torch.long)
    context = context.to(device, dtype = torch.long)
    attention_mask = attention_mask.to(device, dtype = torch.long)
    
    generated_ids = model.generate(
        input_ids = context,
        attention_mask = attention_mask, 
        max_length=150, 
        num_beams=2,
        repetition_penalty=2.5, 
        length_penalty=1.0, 
        early_stopping=True
        )
    preds = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
    target = [tokenizer.decode(t, skip_special_tokens=True, clean_up_tokenization_spaces=True)for t in question]

# %%
preds
# Out:
# ['is a part of the First Year of Studies program?',
#  'is a part of the First Year of Studies program?',
#  'is a part of the First Year of Studies program?',
#  'is a part of the First Year of Studies program?']

# %%
target
# Out:
# ['What entity provides help with the management of time for new students at Notre Dame?',
#  'How many colleges for undergraduates are at Notre Dame?',
#  'What was created at Notre Dame in 1962 to assist first year students?',
#  'Which organization declared the First Year of Studies program at Notre Dame "outstanding?"']

# %%
[tokenizer.decode(c) for c in context]
# Out:
# ["All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>",
#  "All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>",
#  "All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>",
#  "All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>"]

# %%
from util.preprocessing import read_from_json

# %%
df = read_from_json()

# %%
df[df['question'] == df['question'].iloc[409]]
# Out:
#                            id    title  ... answer_end    answer_text
# 288  56d43ce42ccc5a1400d830b6  Beyoncé  ...        530           2003
# 409  56d4b9702ccc5a1400d83173  Beyoncé  ...        242  June 24, 2003
#
# [2 rows x 7 columns]

# %%
import pandas as pd

# %%
duplicated = []
for index, row in df[df.duplicated(['question'])].iterrows():
    duplicated.append(df[df['question'] == row['question']])

# %%
duplicated
# Out:
# [                           id    title  ... answer_end    answer_text
#  288  56d43ce42ccc5a1400d830b6  Beyoncé  ...        530           2003
#  409  56d4b9702ccc5a1400d83173  Beyoncé  ...        242  June 24, 2003
#
#  [2 rows x 7 columns],
#                             id    title  ... answer_end      answer_text
#  525  56be9bb83aeaaa14008c915c  Beyoncé  ...         18  January 7, 2012
#  529  56bfa087a10cfb14005511d9  Beyoncé  ...         18  January 7, 2012
#
#  [2 rows x 7 columns],
#                              id  ...                      answer_text
#  1027  5733bd9bd058e614000b6199  ...  Spanish word montaña (mountain)
#  1031  5733f0e34776f41900661573  ...    from the Spanish word montaña
#
#  [2 rows x 7 columns],
#                              id            title  ... answer_end answer_text
#  1646  56cf66734df3c31400b0d714  Frédéric_Chopin  ...        333        1830
#  1650  56d3123b59d6e41400146205  Frédéric_Chopin  ...        333        1830
#
#  [2 rows x 7 columns],
#                              id            title  ... answer_end answer_text
#  1516  56d1cd98e7d4791d009021e6  Frédéric_Chopin  ...        419        1835
#  1712  56cf6d3e4df3c31400b0d783  Frédéric_Chopin  ...        255        1835
#
#  [2 rows x 7 columns],
#                              id            title  ... answer_end     answer_text
#  1791  56cfdb3e234ae51400d9bf7f  Frédéric_Chopin  ...       1182  Marie d'Agoult
#  1794  56d3227259d6e41400146280  Frédéric_Chopin  ...       1182  Marie d'Agoult
#
#  [2 rows x 7 columns],
#                              id  ...          answer_text
#  1956  56cf5433aab44d1400b88ff1  ...   Alexander Glazunov
#  1960  56d3a9bb2ccc5a1400d82ddc  ...  Alexander Glazunov.
#
#  [2 rows x 7 columns],
#                              id            title  ... answer_end         answer_text
#  1985  56cfe7f4234ae51400d9c060  Frédéric_Chopin  ...         82           Guildhall
#  1988  56d375b859d6e4140014646b  Frédéric_Chopin  ...         82  London's Guildhall
#
#  [2 rows x 7 columns],
#                              id  ...                           answer_text
#  2015  56cfeae2234ae51400d9c0b9  ...               Church of the Madeleine
#  2018  56d38ba459d6e414001466e7  ...  the Church of the Madeleine in Paris
#
#  [2 rows x 7 columns],
#                              id            title  ... answer_end answer_text
#  2016  56cfeae2234ae51400d9c0ba  Frédéric_Chopin  ...         87   two weeks
#  2019  56d38ba459d6e414001466e8  Frédéric_Chopin  ...         87   two weeks
#
#  [2 rows x 7 columns],
#                              id            title  ... answer_end    answer_text
#  2033  56cfec4b234ae51400d9c0d0  Frédéric_Chopin  ...        224  Jane Stirling
#  2037  56d38cc659d6e4140014672d  Frédéric_Chopin  ...        224  Jane Stirling
#
#  [2 rows x 7 columns],
#                              id            title  ... answer_end     answer_text
#  2132  56cff6f3234ae51400d9c193  Frédéric_Chopin  ...        598  Nikolai Zverev
#  2135  56d3a9282ccc5a1400d82dca  Frédéric_Chopin  ...        598  Nikolai Zverev
#
#  [2 rows x 7 columns],
#                              id  ...                              answer_text
#  3378  56cdd63a62d2951400fa68d9  ...  Chengdu Shuangliu International Airport
#  3381  56d5185a9d1b871400ae061c  ...  Chengdu Shuangliu International Airport
#
#  [2 rows x 7 columns],
#                              id                    title  ... answer_end answer_text
#  3444  56cde34662d2951400fa6975  2008_Sichuan_earthquake  ...        161     374,176
#  3449  56d525192593cc1400307ab4  2008_Sichuan_earthquake  ...        161     374,176
#
#  [2 rows x 7 columns],
#                              id  ...   answer_text
#  3572  56cec2a1aab44d1400b889e4  ...  Saudi Arabia
#  3575  56d6696d1c850414009470fc  ...  Saudi Arabia
#
#  [2 rows x 7 columns],
#                              id          title  ... answer_end      answer_text
#  4282  56cf571faab44d1400b8906c  New_York_City  ...         15  I Love New York
#  4284  56cff6a7234ae51400d9c18e  New_York_City  ...         15  I Love New York
#
#  [2 rows x 7 columns],
#                              id  ...                                    answer_text
#  4885  56cfdf65234ae51400d9bfcd  ...                       solar thermal collectors
#  4886  56cfdf65234ae51400d9bfce  ...  designing spaces that naturally circulate air
#
#  [2 rows x 7 columns],
#                              id       title  ... answer_end answer_text
#  5145  573366944776f419006609f5  Tajikistan  ...         83     650–680
#  5149  573366934776f419006609ed  Tajikistan  ...         83     650–680
#  5151  57336693d058e614000b5a2b  Tajikistan  ...         83     650–680
#
#  [3 rows x 7 columns],
#                              id       title  ... answer_end answer_text
#  5146  573366944776f419006609f6  Tajikistan  ...        126    Umayyads
#  5150  573366934776f419006609ee  Tajikistan  ...        126    Umayyads
#  5153  57336693d058e614000b5a2c  Tajikistan  ...        126    Umayyads
#
#  [3 rows x 7 columns],
#                              id       title  ... answer_end answer_text
#  5145  573366944776f419006609f5  Tajikistan  ...         83     650–680
#  5149  573366934776f419006609ed  Tajikistan  ...         83     650–680
#  5151  57336693d058e614000b5a2b  Tajikistan  ...         83     650–680
#
#  [3 rows x 7 columns],
#                              id       title  ... answer_end          answer_text
#  5147  573366944776f419006609f7  Tajikistan  ...        154  The Samanid Empire,
#  5152  573366934776f419006609ef  Tajikistan  ...        154  The Samanid Empire,
#  5154  57336693d058e614000b5a2d  Tajikistan  ...        154  The Samanid Empire,
#
#  [3 rows x 7 columns],
#                              id       title  ... answer_end answer_text
#  5146  573366944776f419006609f6  Tajikistan  ...        126    Umayyads
#  5150  573366934776f419006609ee  Tajikistan  ...        126    Umayyads
#  5153  57336693d058e614000b5a2c  Tajikistan  ...        126    Umayyads
#
#  [3 rows x 7 columns],
#                              id       title  ... answer_end          answer_text
#  5147  573366944776f419006609f7  Tajikistan  ...        154  The Samanid Empire,
#  5152  573366934776f419006609ef  Tajikistan  ...        154  The Samanid Empire,
#  5154  57336693d058e614000b5a2d  Tajikistan  ...        154  The Samanid Empire,
#
#  [3 rows x 7 columns],
#                              id       title  ... answer_end answer_text
#  5148  573366944776f419006609f8  Tajikistan  ...        376    Khorasan
#  5155  57336693d058e614000b5a2e  Tajikistan  ...        376    Khorasan
#  5156  573366934776f419006609f0  Tajikistan  ...        376    Khorasan
#
#  [3 rows x 7 columns],
#                              id       title  ... answer_end answer_text
#  5148  573366944776f419006609f8  Tajikistan  ...        376    Khorasan
#  5155  57336693d058e614000b5a2e  Tajikistan  ...        376    Khorasan
#  5156  573366934776f419006609f0  Tajikistan  ...        376    Khorasan
#
#  [3 rows x 7 columns],
#                              id  ...                         answer_text
#  5189  573353674776f4190066083e  ...  area of 143,100 km2 (55,300 sq mi)
#  5194  5731cfe0b9d445190005e581  ...                         143,100 km2
#
#  [2 rows x 7 columns],
#                              id     title  ... answer_end          answer_text
#  5542  573323754776f419006606fe  Portugal  ...         70  Portuguese Republic
#  5547  57326292e17f3d1400422929  Portugal  ...         70  Portuguese Republic
#  5825  57341fcf4776f419006618cb  Portugal  ...         10           Portuguese
#
#  [3 rows x 7 columns],
#                              id  ...                                answer_text
#  5543  573323754776f419006606ff  ...  Iberian Peninsula, in Southwestern Europe
#  5548  57326292e17f3d140042292a  ...  Iberian Peninsula, in Southwestern Europe
#
#  [2 rows x 7 columns],
#                              id     title  ... answer_end answer_text
#  5686  5733f743d058e614000b6699  Portugal  ...        174        1974
#  5699  5733f9cfd058e614000b66eb  Portugal  ...         38        1974
#
#  [2 rows x 7 columns],
#                              id     title  ... answer_end     answer_text
#  5544  573323754776f41900660700  Portugal  ...        256  Atlantic Ocean
#  5810  5734195bd058e614000b694b  Portugal  ...        193  Atlantic Ocean
#
#  [2 rows x 7 columns],
#                              id     title  ... answer_end          answer_text
#  5542  573323754776f419006606fe  Portugal  ...         70  Portuguese Republic
#  5547  57326292e17f3d1400422929  Portugal  ...         70  Portuguese Republic
#  5825  57341fcf4776f419006618cb  Portugal  ...         10           Portuguese
#
#  [3 rows x 7 columns],
#                              id     title  ... answer_end        answer_text
#  5866  573427dad058e614000b6a34  Portugal  ...        105  late 19th century
#  5869  573427dc4776f419006619af  Portugal  ...        105  late 19th century
#
#  [2 rows x 7 columns],
#                              id  ...                                        answer_text
#  5867  573427dad058e614000b6a35  ...  Arthur Duarte, António Lopes Ribeiro, António ...
#  5870  573427dc4776f419006619b0  ...  Arthur Duarte, António Lopes Ribeiro, António ...
#
#  [2 rows x 7 columns],
#                              id  ...                                        answer_text
#  5868  573427dad058e614000b6a36  ...  Joaquim de Almeida, Daniela Ruah, Maria de Med...
#  5871  573427dc4776f419006619b1  ...  Joaquim de Almeida, Daniela Ruah, Maria de Med...
#
#  [2 rows x 7 columns],
#                              id     title  ... answer_end           answer_text
#  6341  56cff91b234ae51400d9c1bb  Buddhism  ...         36           nontheistic
#  6346  56d0c933234ae51400d9c43c  Buddhism  ...         45  nontheistic religion
#
#  [2 rows x 7 columns],
#                              id          title  ... answer_end       answer_text
#  6975  56d22394e7d4791d0090269c  American_Idol  ...        457    Kelly Clarkson
#  6977  56d22394e7d4791d0090269e  American_Idol  ...        475  Carrie Underwood
#  6978  56d22394e7d4791d0090269f  American_Idol  ...        501          Fantasia
#  6979  56d366bb59d6e414001462ed  American_Idol  ...        475  Carrie Underwood
#  6980  56d366bb59d6e414001462ee  American_Idol  ...        501          Fantasia
#
#  [5 rows x 7 columns],
#                              id          title  ... answer_end       answer_text
#  6975  56d22394e7d4791d0090269c  American_Idol  ...        457    Kelly Clarkson
#  6977  56d22394e7d4791d0090269e  American_Idol  ...        475  Carrie Underwood
#  6978  56d22394e7d4791d0090269f  American_Idol  ...        501          Fantasia
#  6979  56d366bb59d6e414001462ed  American_Idol  ...        475  Carrie Underwood
#  6980  56d366bb59d6e414001462ee  American_Idol  ...        501          Fantasia
#
#  [5 rows x 7 columns],
#                              id          title  ... answer_end       answer_text
#  6975  56d22394e7d4791d0090269c  American_Idol  ...        457    Kelly Clarkson
#  6977  56d22394e7d4791d0090269e  American_Idol  ...        475  Carrie Underwood
#  6978  56d22394e7d4791d0090269f  American_Idol  ...        501          Fantasia
#  6979  56d366bb59d6e414001462ed  American_Idol  ...        475  Carrie Underwood
#  6980  56d366bb59d6e414001462ee  American_Idol  ...        501          Fantasia
#
#  [5 rows x 7 columns],
#                              id          title  ... answer_end       answer_text
#  6975  56d22394e7d4791d0090269c  American_Idol  ...        457    Kelly Clarkson
#  6977  56d22394e7d4791d0090269e  American_Idol  ...        475  Carrie Underwood
#  6978  56d22394e7d4791d0090269f  American_Idol  ...        501          Fantasia
#  6979  56d366bb59d6e414001462ed  American_Idol  ...        475  Carrie Underwood
#  6980  56d366bb59d6e414001462ee  American_Idol  ...        501          Fantasia
#
#  [5 rows x 7 columns],
#                              id          title  ... answer_end   answer_text
#  7235  56db1c21e7c41114004b4d49  American_Idol  ...         15  May 30, 2006
#  7312  56db2056e7c41114004b4db6  American_Idol  ...         90  May 21, 2008
#
#  [2 rows x 7 columns],
#                              id          title  ... answer_end      answer_text
#  7386  56db275ae7c41114004b4e3d  American_Idol  ...         41           DeWyze
#  7422  56db29dae7c41114004b4e7e  American_Idol  ...         64  Scotty McCreery
#  7447  56db2c98e7c41114004b4eb1  American_Idol  ...          8         Phillips
#  7470  56db2df9e7c41114004b4edb  American_Idol  ...         26   Candice Glover
#  7498  56db3123e7c41114004b4f13  American_Idol  ...         13    Caleb Johnson
#  7522  56db3c93e7c41114004b4f77  American_Idol  ...         13    Nick Fradiani
#
#  [6 rows x 7 columns],
#                              id          title  ... answer_end      answer_text
#  7386  56db275ae7c41114004b4e3d  American_Idol  ...         41           DeWyze
#  7422  56db29dae7c41114004b4e7e  American_Idol  ...         64  Scotty McCreery
#  7447  56db2c98e7c41114004b4eb1  American_Idol  ...          8         Phillips
#  7470  56db2df9e7c41114004b4edb  American_Idol  ...         26   Candice Glover
#  7498  56db3123e7c41114004b4f13  American_Idol  ...         13    Caleb Johnson
#  7522  56db3c93e7c41114004b4f77  American_Idol  ...         13    Nick Fradiani
#
#  [6 rows x 7 columns],
#                              id          title  ... answer_end      answer_text
#  7386  56db275ae7c41114004b4e3d  American_Idol  ...         41           DeWyze
#  7422  56db29dae7c41114004b4e7e  American_Idol  ...         64  Scotty McCreery
#  7447  56db2c98e7c41114004b4eb1  American_Idol  ...          8         Phillips
#  7470  56db2df9e7c41114004b4edb  American_Idol  ...         26   Candice Glover
#  7498  56db3123e7c41114004b4f13  American_Idol  ...         13    Caleb Johnson
#  7522  56db3c93e7c41114004b4f77  American_Idol  ...         13    Nick Fradiani
#
#  [6 rows x 7 columns],
#                              id          title  ... answer_end    answer_text
#  7268  56db1dbfe7c41114004b4d7b  American_Idol  ...        103    Blake Lewis
#  7471  56db2df9e7c41114004b4edc  American_Idol  ...         60  Kree Harrison
#
#  [2 rows x 7 columns],
#                              id          title  ... answer_end answer_text
#  7411  56db290be7c41114004b4e65  American_Idol  ...        196      Abrams
#  7491  56db30ede7c41114004b4f0c  American_Idol  ...        146   Sam Woolf
#
#  [2 rows x 7 columns],
#                              id          title  ... answer_end      answer_text
#  7386  56db275ae7c41114004b4e3d  American_Idol  ...         41           DeWyze
#  7422  56db29dae7c41114004b4e7e  American_Idol  ...         64  Scotty McCreery
#  7447  56db2c98e7c41114004b4eb1  American_Idol  ...          8         Phillips
#  7470  56db2df9e7c41114004b4edb  American_Idol  ...         26   Candice Glover
#  7498  56db3123e7c41114004b4f13  American_Idol  ...         13    Caleb Johnson
#  7522  56db3c93e7c41114004b4f77  American_Idol  ...         13    Nick Fradiani
#
#  [6 rows x 7 columns],
#                              id          title  ... answer_end      answer_text
#  7386  56db275ae7c41114004b4e3d  American_Idol  ...         41           DeWyze
#  7422  56db29dae7c41114004b4e7e  American_Idol  ...         64  Scotty McCreery
#  7447  56db2c98e7c41114004b4eb1  American_Idol  ...          8         Phillips
#  7470  56db2df9e7c41114004b4edb  American_Idol  ...         26   Candice Glover
#  7498  56db3123e7c41114004b4f13  American_Idol  ...         13    Caleb Johnson
#  7522  56db3c93e7c41114004b4f77  American_Idol  ...         13    Nick Fradiani
#
#  [6 rows x 7 columns],
#                              id  ...        answer_text
#  8507  56d972eadc89441400fdb48f  ...   Ho Chi Minh City
#  8511  56db6ae2e7c41114004b50bd  ...  Ho Chi Minh City.
#
#  [2 rows x 7 columns],
#                              id  ...        answer_text
#  8632  56d98b11dc89441400fdb534  ...  Shoichi Washizawa
#  8635  56db7c94e7c41114004b51a5  ...  Shoichi Washizawa
#
#  [2 rows x 7 columns],
#                              id  ...                                        answer_text
#  8792  57331bdad058e614000b5707  ...  minister and schoolmaster of Chatham House Aca...
#  8796  57301444947a6a140053d072  ...                          minister and schoolmaster
#
#  [2 rows x 7 columns],
#                               id     title  ... answer_end   answer_text
#  10709  56dfb65b7aa994140058e040  Lighting  ...        317        50,000
#  10710  56dfb65b7aa994140058e041  Lighting  ...        323  50,000 hours
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  11014  56de2d2acffd8e1900b4b627  ...    the IHDI
#  11015  56de3e1bcffd8e1900b4b6d6  ...     the HDI
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  11031  56de30cdcffd8e1900b4b64f  ...        Cuba
#  11038  56de326fcffd8e1900b4b666  ...    Barbados
#  11039  56de423fcffd8e1900b4b727  ...    Barbados
#  11041  56de32ffcffd8e1900b4b66f  ...    Barbados
#  11042  56de42becffd8e1900b4b73a  ...    Barbados
#  11048  56de4421cffd8e1900b4b754  ...    Barbados
#
#  [6 rows x 7 columns],
#                               id  ... answer_text
#  11031  56de30cdcffd8e1900b4b64f  ...        Cuba
#  11038  56de326fcffd8e1900b4b666  ...    Barbados
#  11039  56de423fcffd8e1900b4b727  ...    Barbados
#  11041  56de32ffcffd8e1900b4b66f  ...    Barbados
#  11042  56de42becffd8e1900b4b73a  ...    Barbados
#  11048  56de4421cffd8e1900b4b754  ...    Barbados
#
#  [6 rows x 7 columns],
#                               id  ... answer_text
#  11019  56de3e61cffd8e1900b4b6e6  ...        1990
#  11040  56de32904396321400ee2685  ...        2011
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  11031  56de30cdcffd8e1900b4b64f  ...        Cuba
#  11038  56de326fcffd8e1900b4b666  ...    Barbados
#  11039  56de423fcffd8e1900b4b727  ...    Barbados
#  11041  56de32ffcffd8e1900b4b66f  ...    Barbados
#  11042  56de42becffd8e1900b4b73a  ...    Barbados
#  11048  56de4421cffd8e1900b4b754  ...    Barbados
#
#  [6 rows x 7 columns],
#                               id  ... answer_text
#  11031  56de30cdcffd8e1900b4b64f  ...        Cuba
#  11038  56de326fcffd8e1900b4b666  ...    Barbados
#  11039  56de423fcffd8e1900b4b727  ...    Barbados
#  11041  56de32ffcffd8e1900b4b66f  ...    Barbados
#  11042  56de42becffd8e1900b4b73a  ...    Barbados
#  11048  56de4421cffd8e1900b4b754  ...    Barbados
#
#  [6 rows x 7 columns],
#                               id  ... answer_text
#  11031  56de30cdcffd8e1900b4b64f  ...        Cuba
#  11038  56de326fcffd8e1900b4b666  ...    Barbados
#  11039  56de423fcffd8e1900b4b727  ...    Barbados
#  11041  56de32ffcffd8e1900b4b66f  ...    Barbados
#  11042  56de42becffd8e1900b4b73a  ...    Barbados
#  11048  56de4421cffd8e1900b4b754  ...    Barbados
#
#  [6 rows x 7 columns],
#                               id   title  ... answer_end   answer_text
#  14090  56e032247aa994140058e349  Comics  ...         54  drawn strips
#  14109  56e035be7aa994140058e388  Comics  ...        199   drawn strip
#
#  [2 rows x 7 columns],
#                               id   title  ... answer_end answer_text
#  14802  56e0cfa8231d4119001ac3d5  Boston  ...          6      Boston
#  15093  56e16959cd28a01900c6789b  Boston  ...        156      Boston
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  15209  56e103f6e3433e1400422ab2  ...  to validate frequencies for the BeiDou-2 const...
#  15268  56e1161ccd28a01900c6757a  ...  for signal testing and validation and for the ...
#
#  [2 rows x 7 columns],
#                               id  ...         answer_text
#  15701  56e17b08cd28a01900c679ae  ...  In Central Catalan
#  15730  56e18e18cd28a01900c679c9  ...     Eastern Catalan
#
#  [2 rows x 7 columns],
#                               id title  ... answer_end answer_text
#  17144  56e6ef806fe0821900b8ec42  Bern  ...         71      German
#  17147  56e85fee00c9c71400d77671  Bern  ...         71      German
#
#  [2 rows x 7 columns],
#                               id  ...      answer_text
#  18036  56e80b8000c9c71400d775b5  ...  rule by thieves
#  18039  56e9f4805a205f1900d6d337  ...  rule by thieves
#
#  [2 rows x 7 columns],
#                               id            title  ... answer_end        answer_text
#  18388  56f6ed94711bf01900a44877  Classical_music  ...        672          1400–1600
#  18556  56f73c54aef2371900625a35  Classical_music  ...         41  from 1400 to 1600
#
#  [2 rows x 7 columns],
#                               id            title  ... answer_end answer_text
#  19625  56f715e43d8e2e1400e3732f  Josip_Broz_Tito  ...        827        1980
#  19824  56f81fb1aef2371900625dee  Josip_Broz_Tito  ...        456  4 May 1980
#
#  [2 rows x 7 columns],
#                               id  ...            answer_text
#  19949  56f9525a9b226e1400dd1309  ...  Micronesian colonists
#  19987  56f954419b226e1400dd1330  ...           Micronesians
#
#  [2 rows x 7 columns],
#                               id  ...                 answer_text
#  19994  56f78c18a6d7ea1400e17257  ...  Santa Maria de la Victoria
#  19999  56f954c09b226e1400dd133b  ...  Santa Maria de la Victoria
#
#  [2 rows x 7 columns],
#                               id          title  ... answer_end    answer_text
#  5106   57335842d058e614000b5890     Tajikistan  ...        747   1992 to 1997
#  21357  56f8df889b226e1400dd1150  Guinea-Bissau  ...        225  1998 and 1999
#
#  [2 rows x 7 columns],
#                               id  ...                 answer_text
#  22439  56f9de7f9e9bad19000a0b2d  ...  digital video broadcasting
#  22480  56f9ebe18f12f3190062fffa  ...  Digital Video Broadcasting
#
#  [2 rows x 7 columns],
#                               id         title  ... answer_end      answer_text
#  24046  57064d8c52bb8914006899cf  Black_people  ...         82  Nubian Sudanese
#  24056  5706511d52bb8914006899e2  Black_people  ...        198           Fulani
#
#  [2 rows x 7 columns],
#                               id      title  ... answer_end       answer_text
#  24307  5705de1675f01819005e76c3  The_Times  ...        266  Times Newspapers
#  24309  5705dec952bb891400689639  The_Times  ...        266  Times Newspapers
#
#  [2 rows x 7 columns],
#                               id      title  ... answer_end answer_text
#  24528  5705e3a452bb891400689659  New_Delhi  ...         41   New Delhi
#  24529  5705e3a452bb89140068965a  New_Delhi  ...         27       Delhi
#
#  [2 rows x 7 columns],
#                               id  ...                   answer_text
#  24520  5705e39275f01819005e76e8  ...                      George V
#  24541  5705e3dd75f01819005e76fc  ...  King George V and Queen Mary
#
#  [2 rows x 7 columns],
#                               id      title  ... answer_end        answer_text
#  24651  57068f3a75f01819005e7c08  New_Delhi  ...        550             189 km
#  24653  570691b652bb891400689a6d  New_Delhi  ...        469  189.63 kilometres
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  25234  5706845d52bb891400689a2a  ...        3.34
#  25254  5706bc1f2eaba6190074acd6  ...        3.26
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  25238  5706b8bd0eeca41400aa0dac  ...        96.2
#  25256  5706bd3e0eeca41400aa0dd4  ...        96.1
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  25239  5706b8bd0eeca41400aa0dad  ...        94.4
#  25257  5706bd3e0eeca41400aa0dd5  ...        93.2
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  25243  5706ba0c2eaba6190074ac91  ...     $20,069
#  25262  5706be1e0eeca41400aa0de9  ...     $15,402
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  27787  5709d00a6d058f1900182bb8  ...        1845
#  27792  570a49376d058f1900182d34  ...        1845
#
#  [2 rows x 7 columns],
#                               id  ...               answer_text
#  29309  570b1e4aec8fbc190045b83a  ...  deaf Video Relay Service
#  29312  570b1e4aec8fbc190045b83d  ...              tele-medical
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  30646  570d672cb3d812140066d839  ...            a period of preparation for adult roles
#  30834  570de6db0b85d914000d7ba3  ...  a period of development characterized by a dra...
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end answer_text
#  33497  570e2b700b85d914000d7d00  Eritrea  ...         78    sea-land
#  33510  570e2def0dc6ce1900204e45  Eritrea  ...        344    Sea land
#
#  [2 rows x 7 columns],
#                               id  ...                           answer_text
#  34523  570f8a7d5ab6b81900390f03  ...  genetic, hormonal, and environmental
#  34528  570fa05680d9841400ab35dd  ...  genetic, hormonal, and environmental
#
#  [2 rows x 7 columns],
#                               id  ...                                answer_text
#  34548  570fa2a35ab6b81900390f49  ...  desire for a perceived traditional family
#  34549  570fa2a35ab6b81900390f4a  ...                 concerns of discrimination
#  34550  570fa2a35ab6b81900390f4b  ...                        religious ostracism
#
#  [3 rows x 7 columns],
#                               id  ...                                answer_text
#  34548  570fa2a35ab6b81900390f49  ...  desire for a perceived traditional family
#  34549  570fa2a35ab6b81900390f4a  ...                 concerns of discrimination
#  34550  570fa2a35ab6b81900390f4b  ...                        religious ostracism
#
#  [3 rows x 7 columns],
#                               id  ...                                        answer_text
#  34551  570fa2a35ab6b81900390f4c  ...  develop positive gay and lesbian identities wh...
#  34552  570fa2a35ab6b81900390f4d  ...  hide their respective orientations from their ...
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  34559  570fa35780d9841400ab35e9  ...  American Psychiatric Association, American Psy...
#  34560  570fa35780d9841400ab35ea  ...  National Association of Social Workers in the ...
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  36290  571a48dd10f8ca1400304fcd  ...  defining as black, persons with any known Afri...
#  36294  571aa01210f8ca14003051d3  ...    black, persons with any known African ancestry.
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  36303  571a8c4810f8ca140030510d  ...  In the 2010 US census, approximately 9 million...
#  36308  571a94b04faf5e1900b8aac4  ...  In the 2010 US census, approximately 9 million...
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  36307  571a8c4810f8ca1400305110  ...  Multiracial Americans are Americans who have m...
#  36309  571a94b04faf5e1900b8aac5  ...  Multiracial Americans are Americans who have m...
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  36304  571a8c4810f8ca1400305111  ...  many people hid their multiracial heritage bec...
#  36310  571a94b04faf5e1900b8aac6  ...  Prior to the mid-20th century, many people hid...
#
#  [2 rows x 7 columns],
#                               id  ...                            answer_text
#  36313  571da1b05569731900639056  ...  mixed ancestry of "two or more races"
#  36318  571dd9035569731900639060  ...                      two or more races
#
#  [2 rows x 7 columns],
#                               id  ...                          answer_text
#  36314  571da1b05569731900639057  ...  approximately 9 million individuals
#  36319  571dd9035569731900639061  ...  approximately 9 million individuals
#
#  [2 rows x 7 columns],
#                               id  ...           answer_text
#  36315  571da1b05569731900639058  ...  the mid-20th century
#  36320  571dd9035569731900639063  ...  the mid-20th century
#
#  [2 rows x 7 columns],
#                               id  ...                              answer_text
#  36376  571deae4b64a571400c71e04  ...                      if adopted by a man
#  36466  571e03b5556973190063910c  ...  adopted into the tribe by an adult male
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  36480  571a6dbe4faf5e1900b8a9a2  ...   Adrenalin
#  36485  571a79d910f8ca1400305086  ...   Adrenalin
#
#  [2 rows x 7 columns],
#                               id  ...       answer_text
#  36582  571ab7b210f8ca1400305310  ...  Maurice Hilleman
#  36588  571cfbd6dd7acb1400e4c1df  ...  Maurice Hilleman
#
#  [2 rows x 7 columns],
#                               id           title  ... answer_end answer_text
#  37172  5722c9db0dadf01500fa1eeb  Queen_Victoria  ...        271        1861
#  37182  572413c70ba9f01400d97b6c  Queen_Victoria  ...        271        1861
#
#  [2 rows x 7 columns],
#                               id           title  ... answer_end answer_text
#  37174  5723aae60dadf01500fa1f27  Queen_Victoria  ...         94        nine
#  37188  572431470ba9f01400d97b77  Queen_Victoria  ...         94        nine
#
#  [2 rows x 7 columns],
#                               id  ...                             answer_text
#  37169  5722c9db0dadf01500fa1ee9  ...                           Prince Albert
#  37189  57257a9769ff041400e58df4  ...  Prince Albert of Saxe-Coburg and Gotha
#
#  [2 rows x 7 columns],
#                               id           title  ... answer_end answer_text
#  37284  5722cddcf6b826140030fc50  Queen_Victoria  ...        230        1894
#  37289  5723d221f6b826140030fc96  Queen_Victoria  ...        230        1894
#
#  [2 rows x 7 columns],
#                               id           title  ... answer_end answer_text
#  37342  5723d6630dadf01500fa1f48  Queen_Victoria  ...        855   Melbourne
#  37353  57262ed2271a42140099d71b  Queen_Victoria  ...        855   Melbourne
#
#  [2 rows x 7 columns],
#                               id           title  ... answer_end answer_text
#  37590  5723f6f7f6b826140030fd0c  Queen_Victoria  ...        111          71
#  37601  572663fbf1498d1400e8ddff  Queen_Victoria  ...        111          71
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  37559  5723f4900dadf01500fa1fb9  ...  Prince Edward, Duke of Kent and Strathearn, th...
#  37662  5723fd980ba9f01400d97b05  ...         Prince Edward, Duke of Kent and Strathearn
#  37667  5723fd9a0a492a19004355ce  ...         Prince Edward, Duke of Kent and Strathearn
#
#  [3 rows x 7 columns],
#                               id  ...                                        answer_text
#  37559  5723f4900dadf01500fa1fb9  ...  Prince Edward, Duke of Kent and Strathearn, th...
#  37662  5723fd980ba9f01400d97b05  ...         Prince Edward, Duke of Kent and Strathearn
#  37667  5723fd9a0a492a19004355ce  ...         Prince Edward, Duke of Kent and Strathearn
#
#  [3 rows x 7 columns],
#                               id  ...          answer_text
#  37714  57267189708984140094c63f  ...           acid spray
#  37717  57267f57f1498d1400e8e1cb  ...  carbolic acid spray
#
#  [2 rows x 7 columns],
#                               id               title  ... answer_end answer_text
#  38422  57262473271a42140099d4e9  Hellenistic_period  ...       1111   yptian Se
#  38423  57262473271a42140099d4ea  Hellenistic_period  ...       1190       Buddh
#  38424  57262473271a42140099d4eb  Hellenistic_period  ...        922     m and E
#  38425  57262473271a42140099d4ec  Hellenistic_period  ...       1193    Buddhism
#
#  [4 rows x 7 columns],
#                               id               title  ... answer_end answer_text
#  38422  57262473271a42140099d4e9  Hellenistic_period  ...       1111   yptian Se
#  38423  57262473271a42140099d4ea  Hellenistic_period  ...       1190       Buddh
#  38424  57262473271a42140099d4eb  Hellenistic_period  ...        922     m and E
#  38425  57262473271a42140099d4ec  Hellenistic_period  ...       1193    Buddhism
#
#  [4 rows x 7 columns],
#                               id               title  ... answer_end answer_text
#  38422  57262473271a42140099d4e9  Hellenistic_period  ...       1111   yptian Se
#  38423  57262473271a42140099d4ea  Hellenistic_period  ...       1190       Buddh
#  38424  57262473271a42140099d4eb  Hellenistic_period  ...        922     m and E
#  38425  57262473271a42140099d4ec  Hellenistic_period  ...       1193    Buddhism
#
#  [4 rows x 7 columns],
#                               id               title  ... answer_end     answer_text
#  38455  5725b74c271a42140099d089  Hellenistic_period  ...        700  Matthew Arnold
#  38461  572802574b864d1900164201  Hellenistic_period  ...        700  Matthew Arnold
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  38466  572628a738643c19005ad190  ...                                              moved
#  38536  572628deec44d21400f3daaf  ...                                              refor
#  38546  572628f0271a42140099d623  ...                                             tes (3
#  38676  57262957ec44d21400f3daff  ...                                               y of
#  38704  5726298fec44d21400f3db08  ...  dom. The resulting Indo-Scythian kingdom seems...
#  38705  5726298fec44d21400f3db09  ...                                                 in
#
#  [6 rows x 7 columns],
#                               id  ...                                        answer_text
#  38466  572628a738643c19005ad190  ...                                              moved
#  38536  572628deec44d21400f3daaf  ...                                              refor
#  38546  572628f0271a42140099d623  ...                                             tes (3
#  38676  57262957ec44d21400f3daff  ...                                               y of
#  38704  5726298fec44d21400f3db08  ...  dom. The resulting Indo-Scythian kingdom seems...
#  38705  5726298fec44d21400f3db09  ...                                                 in
#
#  [6 rows x 7 columns],
#                               id  ...                                        answer_text
#  38466  572628a738643c19005ad190  ...                                              moved
#  38536  572628deec44d21400f3daaf  ...                                              refor
#  38546  572628f0271a42140099d623  ...                                             tes (3
#  38676  57262957ec44d21400f3daff  ...                                               y of
#  38704  5726298fec44d21400f3db08  ...  dom. The resulting Indo-Scythian kingdom seems...
#  38705  5726298fec44d21400f3db09  ...                                                 in
#
#  [6 rows x 7 columns],
#                               id  ...                                        answer_text
#  38466  572628a738643c19005ad190  ...                                              moved
#  38536  572628deec44d21400f3daaf  ...                                              refor
#  38546  572628f0271a42140099d623  ...                                             tes (3
#  38676  57262957ec44d21400f3daff  ...                                               y of
#  38704  5726298fec44d21400f3db08  ...  dom. The resulting Indo-Scythian kingdom seems...
#  38705  5726298fec44d21400f3db09  ...                                                 in
#
#  [6 rows x 7 columns],
#                               id  ...                                        answer_text
#  38466  572628a738643c19005ad190  ...                                              moved
#  38536  572628deec44d21400f3daaf  ...                                              refor
#  38546  572628f0271a42140099d623  ...                                             tes (3
#  38676  57262957ec44d21400f3daff  ...                                               y of
#  38704  5726298fec44d21400f3db08  ...  dom. The resulting Indo-Scythian kingdom seems...
#  38705  5726298fec44d21400f3db09  ...                                                 in
#
#  [6 rows x 7 columns],
#                               id     title  ... answer_end answer_text
#  38892  57263f11ec44d21400f3dcba  Napoleon  ...        131  5 May 1821
#  38896  572649185951b619008f6f0e  Napoleon  ...        131  5 May 1821
#
#  [2 rows x 7 columns],
#                               id     title  ... answer_end            answer_text
#  38894  57263f11ec44d21400f3dcbc  Napoleon  ...        227  the French Revolution
#  38897  572649185951b619008f6f10  Napoleon  ...        227  the French Revolution
#
#  [2 rows x 7 columns],
#                               id     title  ... answer_end answer_text
#  38919  5725b60289a1e219009abd31  Napoleon  ...        221   six years
#  38925  57264acb708984140094c1ab  Napoleon  ...        221   six years
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end       answer_text
#  39652  5725b53c38643c19005acb99  Hokkien  ...        383  southern Fujian.
#  39656  5726266789a1e219009ac3e3  Hokkien  ...        382   southern Fujian
#
#  [2 rows x 7 columns],
#                               id              title  ... answer_end      answer_text
#  40576  572604d7ec44d21400f3d803  Buckingham_Palace  ...        247  King George III
#  40623  572610b9271a42140099d41a  Buckingham_Palace  ...        366       George III
#
#  [2 rows x 7 columns],
#                               id              title  ... answer_end answer_text
#  37193  57257a9769ff041400e58df8     Queen_Victoria  ...        271        1861
#  40667  5726151f38643c19005acfc5  Buckingham_Palace  ...         15        1861
#
#  [2 rows x 7 columns],
#                               id              title  ... answer_end    answer_text
#  40720  5725ea96271a42140099d313  Buckingham_Palace  ...        673  more than 800
#  40725  572625bf89a1e219009ac3a9  Buckingham_Palace  ...        680     800 people
#
#  [2 rows x 7 columns],
#                               id  ...            answer_text
#  40755  5725ef6e271a42140099d342  ...  the palace's Ballroom
#  40758  57261d0d38643c19005ad02f  ...               Ballroom
#
#  [2 rows x 7 columns],
#                               id              title  ... answer_end answer_text
#  40769  5725f1dc271a42140099d353  Buckingham_Palace  ...         63        Nash
#  40774  57261ed8ec44d21400f3d921  Buckingham_Palace  ...         63        Nash
#
#  [2 rows x 7 columns],
#                               id  ...           answer_text
#  40771  5725f1dc271a42140099d355  ...  Sir William Chambers
#  40776  57261ed8ec44d21400f3d923  ...  Sir William Chambers
#
#  [2 rows x 7 columns],
#                               id  ...             answer_text
#  41335  5725ffe1ec44d21400f3d7f1  ...                 sixteen
#  41338  5726e32d5951b619008f8179  ...  sixteen federal states
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  41936  5726113689a1e219009ac1cc  ...  routinely invoke legal and technological measures
#  41941  5726ce13dd62a815002e90d0  ...                                      copyright law
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  41938  5726113689a1e219009ac1ce  ...  The copyright holder is typically the work's c...
#  41942  5726ce13dd62a815002e90d2  ...                                     work's creator
#
#  [2 rows x 7 columns],
#                               id  ...             answer_text
#  41940  5726113689a1e219009ac1d0  ...  Copyright infringement
#  41943  5726ce13dd62a815002e90d3  ...  copyright infringement
#
#  [2 rows x 7 columns],
#                               id  ...               answer_text
#  41939  5726113689a1e219009ac1cf  ...  to make derivative works
#  41944  5726ce13dd62a815002e90d4  ...          derivative works
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  41947  5726199989a1e219009ac25c  ...  expanding copyright law to recognize and penal...
#  41950  5726cfd6dd62a815002e9104  ...                            expanding copyright law
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  41948  5726199989a1e219009ac25d  ...  sometimes prosecuted via the criminal justice ...
#  41951  5726cfd6dd62a815002e9105  ...         prosecuted via the criminal justice system
#
#  [2 rows x 7 columns],
#                               id  ...          answer_text
#  42622  5726240738643c19005ad078  ...  Sir James Lancaster
#  42624  572651775951b619008f6fbf  ...  Sir James Lancaster
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  42629  57262557ec44d21400f3da05  ...  town of Machilipatnam on the Coromandel Coast ...
#  42633  5726535d708984140094c277  ...                                      Machilipatnam
#
#  [2 rows x 7 columns],
#                               id  ...                      answer_text
#  42639  57262779271a42140099d5ef  ...  Dutch United East India Company
#  42642  572655495951b619008f6fef  ...                            Dutch
#
#  [2 rows x 7 columns],
#                               id  ...                     answer_text
#  42665  57262e0289a1e219009ac514  ...                         500,000
#  42671  57265ab2f1498d1400e8dcf8  ...  500,000 gold and silver pieces
#
#  [2 rows x 7 columns],
#                               id      title  ... answer_end answer_text
#  21944  56f8e8659e9bad19000a06f3  Near_East  ...        166   1853–1856
#  43739  57268623f1498d1400e8e2aa    Germans  ...        610        1856
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  44476  572643ee1125e71900ae1918  ...       third
#  44479  572678ca5951b619008f73af  ...       third
#
#  [2 rows x 7 columns],
#                               id  ...               answer_text
#  44700  572647aa5951b619008f6ed5  ...  chest pain or discomfort
#  44713  57264bf3f1498d1400e8db68  ...                Chest pain
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  45675  5726aeecdd62a815002e8ce6  ...  the predator's direct impact on the prey popul...
#  45677  5726bd4cdd62a815002e8ee4  ...    predator's direct impact on the prey population
#
#  [2 rows x 7 columns],
#                               id title  ... answer_end  answer_text
#  47740  57267331708984140094c68c  Jews  ...        220  0.4 million
#  47824  57279d5a3acd2414000de7ea  Jews  ...        377      315,000
#
#  [2 rows x 7 columns],
#                               id  ...                     answer_text
#  48313  5726bb79f1498d1400e8e955  ...  the London Metropolitan Police
#  48315  5726c173f1498d1400e8ea4f  ...      London Metropolitan Police
#
#  [2 rows x 7 columns],
#                               id  ...        answer_text
#  49471  5726a86a708984140094cd1d  ...     pointed arches
#  49472  5726a86a708984140094cd1e  ...  flying buttresses
#  49473  5726a86a708984140094cd1f  ...    ribbed vaulting
#
#  [3 rows x 7 columns],
#                               id  ...        answer_text
#  49471  5726a86a708984140094cd1d  ...     pointed arches
#  49472  5726a86a708984140094cd1e  ...  flying buttresses
#  49473  5726a86a708984140094cd1f  ...    ribbed vaulting
#
#  [3 rows x 7 columns],
#                               id  ...              answer_text
#  20188  56f970019b226e1400dd145e  ...  the meat of the coconut
#  50301  5726c63ddd62a815002e8fec  ...       dried coconut meat
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  51367  5726ab2ef1498d1400e8e694  ...  A nonprofit organization (NPO, also known as a...
#  51372  5726aebf708984140094cdc9  ...  furthering a particular social cause or advoca...
#
#  [2 rows x 7 columns],
#                               id  ...                       answer_text
#  51490  5726abb3dd62a815002e8c7a  ...   North Carolina State University
#  51501  5726acc95951b619008f79be  ...  North Carolina State University,
#
#  [2 rows x 7 columns],
#                               id  ...                      answer_text
#  25963  57070af49e06ca38007e92f5  ...  The Treaty of Guadalupe Hidalgo
#  51951  5726b702f1498d1400e8e8a8  ...                  Treaty of Paris
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end              answer_text
#  52714  5726c788dd62a815002e9009  Bermuda  ...        325  Bermuda petrel or cahow
#  52718  5729340aaf94a219006aa186  Bermuda  ...        325  Bermuda petrel or cahow
#
#  [2 rows x 7 columns],
#                               id           title  ... answer_end answer_text
#  54117  5726f152f1498d1400e8f0a0  Czech_language  ...        417        1968
#  54124  572b6d5934ae481900deadfa  Czech_language  ...        417        1968
#
#  [2 rows x 7 columns],
#                               id           title  ... answer_end answer_text
#  54116  572b6c54f75d5e190021fdc5  Czech_language  ...        288       Czech
#  54176  572b8f5d111d821400f38f10  Czech_language  ...          5       Czech
#
#  [2 rows x 7 columns],
#                               id            title  ... answer_end answer_text
#  54546  572929766aef051400154b03  Planck_constant  ...        571        1911
#  54550  5729636c3f37b31900478309  Planck_constant  ...        571        1911
#
#  [2 rows x 7 columns],
#                               id  ...                 answer_text
#  54553  57292b05af94a219006aa14b  ...  Alexandre Edmond Becquerel
#  54559  57296497af94a219006aa374  ...  Alexandre Edmond Becquerel
#
#  [2 rows x 7 columns],
#                               id   title  ... answer_end answer_text
#  55291  57279202dd62a815002ea0b6  FA_Cup  ...        257        1993
#  55295  572792fdf1498d1400e8fc99  FA_Cup  ...        166        1894
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  56210  5727839a5951b619008f8be7  ...     Wallace
#  56211  5727839a5951b619008f8be8  ...      Darwin
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  56558  572815a13acd2414000df41b  ...      troops
#  56586  572821923acd2414000df532  ...     militia
#
#  [2 rows x 7 columns],
#                               id  ...                         answer_text
#  56723  572772c2f1498d1400e8f867  ...  hung between two convicted thieves
#  56761  572782fadd62a815002e9f40  ...                             Calvary
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  57186  572773f6708984140094ddee  ...  the production of a "critical edition" contain...
#  57206  57277992dd62a815002e9dee  ...                               a "critical edition"
#
#  [2 rows x 7 columns],
#                               id  ...                                   answer_text
#  63147  572827843acd2414000df5ad  ...                                         limbs
#  63154  5728283a2ca10214002d9f73  ...  unjointed paired extensions of the body wall
#
#  [2 rows x 7 columns],
#                               id title  ... answer_end                 answer_text
#  63281  572bf917750c471900ed4c4f   God  ...        256  God is the universe itself
#  63347  572c010e750c471900ed4c70   God  ...         40         God is the universe
#  63352  572c0112dfb02c14005c6b45   God  ...         40         God is the universe
#
#  [3 rows x 7 columns],
#                               id title  ... answer_end                 answer_text
#  63281  572bf917750c471900ed4c4f   God  ...        256  God is the universe itself
#  63347  572c010e750c471900ed4c70   God  ...         40         God is the universe
#  63352  572c0112dfb02c14005c6b45   God  ...         40         God is the universe
#
#  [3 rows x 7 columns],
#                               id title  ... answer_end     answer_text
#  63426  572c0bcb750c471900ed4c91   God  ...        149  a personal God
#  63429  572c0bcb750c471900ed4c94   God  ...        316       forgiving
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  64053  572a10fe3f37b31900478691  ...  they speak an entirely separate language from ...
#  64054  572a119a6aef05140015522c  ...  they speak an entirely separate language from ...
#
#  [2 rows x 7 columns],
#                               id       title  ... answer_end       answer_text
#  60539  572803362ca10214002d9b6e  Strasbourg  ...       1032  23 November 1944
#  65360  5728c3cf2ca10214002da73e       Paris  ...        422    25 August 1944
#
#  [2 rows x 7 columns],
#                               id   title  ... answer_end answer_text
# ...
#  25483  570629ba52bb891400689916           MP3  ...        246  Compact Disc
#  74369  572ec5f7cb0c0d14000f1537  Compact_disc  ...         12  Compact Disc
#
#  [2 rows x 7 columns],
#                               id  ...               answer_text
#  74370  572ec5f7cb0c0d14000f1538  ...  Super Video Compact Disc
#  74372  572f5fe6947a6a140053c8db  ...  Super Video Compact Disc
#
#  [2 rows x 7 columns],
#                               id         title  ... answer_end answer_text
#  74377  572ec816c246551400ce4659  Compact_disc  ...          7        2004
#  74380  572f6096b2c2fd140056808d  Compact_disc  ...         81  30 billion
#
#  [2 rows x 7 columns],
#                               id  ...                                      answer_text
#  74379  572ec816c246551400ce465a  ...  other forms of digital storage and distribution
#  74382  572f6096b2c2fd140056808e  ...                   other forms of digital storage
#  74423  572f657cb2c2fd14005680c5  ...             Internet-based distribution of files
#
#  [3 rows x 7 columns],
#                               id  ...                               answer_text
#  74385  572ec92bdfa6aa1500f8d3b7  ...  the cooperation between Philips and Sony
#  74390  572f6c84b2c2fd1400568103  ...      cooperation between Philips and Sony
#
#  [2 rows x 7 columns],
#                               id  ...               answer_text
#  74398  572ecf7bcb0c0d14000f15cb  ...  a Betamax video recorder
#  74400  572f62b404bcaa1900d768b5  ...    Betamax video recorder
#
#  [2 rows x 7 columns],
#                               id         title  ... answer_end answer_text
#  74409  572ed426dfa6aa1500f8d41e  Compact_disc  ...        792          15
#  74411  572f63fc04bcaa1900d768cb  Compact_disc  ...        792          15
#
#  [2 rows x 7 columns],
#                               id         title  ... answer_end     answer_text
#  74374  572f5fe6947a6a140053c8de  Compact_disc  ...         56    data storage
#  74414  572ed6a6dfa6aa1500f8d43b  Compact_disc  ...        167  musical format
#
#  [2 rows x 7 columns],
#                               id  ...            answer_text
#  74416  572ed6a6dfa6aa1500f8d43d  ...  the gramophone record
#  74417  572f6486b2c2fd14005680af  ...      gramophone record
#
#  [2 rows x 7 columns],
#                               id         title  ... answer_end answer_text
#  74418  572eda3ec246551400ce4726  Compact_disc  ...        173   the 2000s
#  74422  572f657cb2c2fd14005680c4  Compact_disc  ...        173       2000s
#
#  [2 rows x 7 columns],
#                               id  ...                                      answer_text
#  74379  572ec816c246551400ce465a  ...  other forms of digital storage and distribution
#  74382  572f6096b2c2fd140056808e  ...                   other forms of digital storage
#  74423  572f657cb2c2fd14005680c5  ...             Internet-based distribution of files
#
#  [3 rows x 7 columns],
#                               id  ...                answer_text
#  2612   56cc858b6d243a140015efec  ...  Digital Rights Management
#  74445  572f6a6504bcaa1900d76904  ...  digital rights management
#
#  [2 rows x 7 columns],
#                               id  ...                   answer_text
#  75119  573071c5069b5314008320d7  ...                          Guam
#  75120  573071c5069b5314008320d8  ...  United States Virgin Islands
#
#  [2 rows x 7 columns],
#                               id  ...         answer_text
#  75278  572ff30304bcaa1900d76f11  ...  impedance matching
#  75285  572ff31bb2c2fd140056863e  ...           bandwidth
#
#  [2 rows x 7 columns],
#                               id            title  ... answer_end  answer_text
#  75320  57300832a23a5019007fcc76  Antenna_(radio)  ...        804  thick tubes
#  75322  573008dba23a5019007fcc7b  Antenna_(radio)  ...        137        cages
#
#  [2 rows x 7 columns],
#                               id  ...           answer_text
#  75352  57301633a23a5019007fcd41  ...  magnetic core losses
#  75353  57301633a23a5019007fcd42  ...           transmitter
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  26985  57096d7eed30961900e840f8  ...                 state-owned television broadcaster
#  75811  572fbe94947a6a140053cc26  ...  the Government of India's public service broad...
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  77491  572fb14eb2c2fd1400568366  ...  It is currently sponsored by Barclays Bank and...
#  77496  5733dfd24776f419006613eb  ...                                      Barclays Bank
#
#  [2 rows x 7 columns],
#                               id  ...                                    answer_text
#  77510  572fb545b2c2fd140056838d  ...  a potential TV audience of 4.7 billion people
#  77517  5733e19dd058e614000b64ad  ...                                    4.7 billion
#
#  [2 rows x 7 columns],
#                               id           title  ... answer_end answer_text
#  77628  5733ec05d058e614000b65e2  Premier_League  ...         84      August
#  77629  5733ec05d058e614000b65e3  Premier_League  ...         91         May
#
#  [2 rows x 7 columns],
#                               id        title  ... answer_end        answer_text
#  16913  56e792e237bdd419002c417f      Nanjing  ...        100               1931
#  78244  5731b1060fdd8d15006c6466  Pacific_War  ...        498  19 September 1931
#
#  [2 rows x 7 columns],
#                               id        title  ... answer_end       answer_text
#  78257  5731b3cab9d445190005e483  Pacific_War  ...        589  2 September 1945
#  78610  57324e4cb9d445190005ea08  Pacific_War  ...        273         15 August
#
#  [2 rows x 7 columns],
#                               id             title  ... answer_end      answer_text
#  49239  5727657f708984140094dcf7  Late_Middle_Ages  ...         15  Dante Alighieri
#  79225  572ff2f6947a6a140053ce5d      Muslim_world  ...         15  Dante Alighieri
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end          answer_text
#  80555  573084ab396df91900096166  Airport  ...        130  air traffic control
#  80599  57309103069b531400832191  Airport  ...        208  air traffic control
#
#  [2 rows x 7 columns],
#                               id             title  ... answer_end answer_text
#  11151  56de4fd0cffd8e1900b4b7f4   Southern_Europe  ...        478        1991
#  81763  5730f53c05b4da19006bcc92  Russian_language  ...        356        1991
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  82919  57317b1d497a881900248f71  ...     Morales
#  82924  57317b1de6313a140071cf86  ...     Morales
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  82920  57317b1d497a881900248f72  ...        2009
#  82925  57317b1de6313a140071cf87  ...        2009
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  82921  57317b1d497a881900248f73  ...  affirm the right of indigenous people to gover...
#  82926  57317b1de6313a140071cf88  ...  affirm the right of indigenous people to gover...
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  82922  57317b1d497a881900248f74  ...       fight
#  82927  57317b1de6313a140071cf89  ...       fight
#
#  [2 rows x 7 columns],
#                               id  ... answer_text
#  82923  57317b1d497a881900248f75  ...     divided
#  82928  57317b1de6313a140071cf8a  ...     divided
#
#  [2 rows x 7 columns],
#                               id  ...  answer_text
#  82992  5731a5edb9d445190005e42f  ...  0.97% to 2%
#  82997  5731a5ede17f3d14004222a5  ...  0.97% to 2%
#
#  [2 rows x 7 columns],
#                               id  ...  answer_text
#  82994  5731a5edb9d445190005e431  ...  1.8 million
#  82998  5731a5ede17f3d14004222a7  ...  1.8 million
#
#  [2 rows x 7 columns],
#                               id  ...  answer_text
#  82993  5731a5edb9d445190005e430  ...  5.2 million
#  82999  5731a5ede17f3d14004222a6  ...  5.2 million
#
#  [2 rows x 7 columns],
#                               id  ...    answer_text
#  82996  5731a5edb9d445190005e433  ...  Haudenosaunee
#  83000  5731a5ede17f3d14004222a9  ...  Haudenosaunee
#
#  [2 rows x 7 columns],
#                               id  ...          answer_text
#  82995  5731a5edb9d445190005e432  ...  Indian reservations
#  83001  5731a5ede17f3d14004222a8  ...  Indian reservations
#
#  [2 rows x 7 columns],
#                               id  ...        answer_text
#  61627  572834c53acd2414000df6e5  ...  28 September 1970
#  83126  57315e23e6313a140071ce9e  ...               1970
#
#  [2 rows x 7 columns],
#                               id  title  ... answer_end    answer_text
#  83104  5731583a497a881900248e43  Egypt  ...         75           1869
#  83235  5731d33d0fdd8d15006c658e  Egypt  ...        216  November 1869
#
#  [2 rows x 7 columns],
#                               id          title  ... answer_end          answer_text
#  23646  56fb9055b28b3419009f1e2e    Middle_Ages  ...        585  burned at the stake
#  84556  5731c670b9d445190005e52d  Protestantism  ...        294  burned at the stake
#
#  [2 rows x 7 columns],
#                               id      title  ... answer_end answer_text
#  86247  57326c89e99e3014001e679e  The_Bronx  ...         40        1974
#  86250  57326c8b0fdd8d15006c6abf  The_Bronx  ...         40        1974
#
#  [2 rows x 7 columns],
#                               id      title  ... answer_end answer_text
#  86249  57326c89e99e3014001e679f  The_Bronx  ...        103        1979
#  86251  57326c8b0fdd8d15006c6ac0  The_Bronx  ...        103        1979
#
#  [2 rows x 7 columns],
#                               id      title  ... answer_end answer_text
#  86246  57326c89e99e3014001e67a0  The_Bronx  ...        248        1979
#  86252  57326c8b0fdd8d15006c6ac1  The_Bronx  ...        248        1979
#
#  [2 rows x 7 columns],
#                               id      title  ... answer_end answer_text
#  86248  57326c89e99e3014001e67a1  The_Bronx  ...        446        1993
#  86253  57326c8b0fdd8d15006c6ac2  The_Bronx  ...        446        1993
#
#  [2 rows x 7 columns],
#                               id     title  ... answer_end          answer_text
#  86302  57327ad70fdd8d15006c6afa  Humanism  ...        146  1,000 BCE – 600 BCE
#  86303  57327ad70fdd8d15006c6afb  Humanism  ...        660            afterlife
#
#  [2 rows x 7 columns],
#                               id     title  ... answer_end      answer_text
#  86306  57327bd90fdd8d15006c6b02  Humanism  ...        304     Duke of Zhou
#  86307  57327bd90fdd8d15006c6b03  Humanism  ...        462  Book of History
#
#  [2 rows x 7 columns],
#                               id     title  ... answer_end      answer_text
#  86319  57327da60fdd8d15006c6b28  Humanism  ...        584           Cicero
#  86320  57327da60fdd8d15006c6b27  Humanism  ...        391  age of Darkness
#
#  [2 rows x 7 columns],
#                               id  ...                     answer_text
#  86322  57327e1757eb1f1400fd2d31  ...  Renaissance Church authorities
#  86323  57327e1757eb1f1400fd2d32  ...      era of universal agreement
#
#  [2 rows x 7 columns],
#                               id     title  ... answer_end        answer_text
#  86328  57327ed206a3a419008aca8c  Humanism  ...        928   Byzantine Empire
#  86329  57327ed206a3a419008aca8d  Humanism  ...       1279  Greek manuscripts
#
#  [2 rows x 7 columns],
#                               id     title  ... answer_end answer_text
#  86330  57327f3657eb1f1400fd2d38  Humanism  ...         10        1517
#  86331  57327f3657eb1f1400fd2d39  Humanism  ...        108     Erasmus
#
#  [2 rows x 7 columns],
#                               id   title  ... answer_end    answer_text
#  86531  573297e560535514009162f8  Police  ...        548  through taxes
#  86535  573297e90d034c1900ab0035  Police  ...        548  through taxes
#
#  [2 rows x 7 columns],
#                               id   title  ... answer_end    answer_text
#  86533  573297e560535514009162f9  Police  ...        503  public sector
#  86536  573297e90d034c1900ab0036  Police  ...        503  public sector
#
#  [2 rows x 7 columns],
#                               id  ...                         answer_text
#  86532  573297e560535514009162fa  ...  late 18th and early 19th centuries
#  86537  573297e90d034c1900ab0037  ...  late 18th and early 19th centuries
#
#  [2 rows x 7 columns],
#                               id   title  ... answer_end answer_text
#  86534  573297e560535514009162fb  Police  ...        428  corruption
#  86538  573297e90d034c1900ab0038  Police  ...        428  corruption
#
#  [2 rows x 7 columns],
#                               id  ...                                        answer_text
#  86549  57329bc4328d981900601fd5  ...  The Marshal of France and the Constable of France
#  86554  57329bc4cc179a14009dab68  ...  The Marshal of France and the Constable of France
#
#  [2 rows x 7 columns],
#                               id  ...                            answer_text
#  86550  57329bc4328d981900601fd6  ...  Great Officers of the Crown of France
#  86555  57329bc4cc179a14009dab69  ...  Great Officers of the Crown of France
#
#  [2 rows x 7 columns],
#                               id   title  ... answer_end    answer_text
#  86551  57329bc4328d981900601fd7  Police  ...        311  the Marshalcy
#  86556  57329bc4cc179a14009dab6a  Police  ...        311  the Marshalcy
#
#  [2 rows x 7 columns],
#                               id   title  ... answer_end       answer_text
#  86552  57329bc4328d981900601fd8  Police  ...        523  the Constabulary
#  86557  57329bc4cc179a14009dab6b  Police  ...        523  the Constabulary
#
#  [2 rows x 7 columns],
#                               id   title  ... answer_end  answer_text
#  86553  57329bc4328d981900601fd9  Police  ...        544  Connétablie
#  86558  57329bc4cc179a14009dab6c  Police  ...        544  Connétablie
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end answer_text
#  86972  5735ab1adc94161900571efe  Hunting  ...        300       2010s
#  86979  5735d85d012e2f140011a0b8  Hunting  ...        300       2010s
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end            answer_text
#  87000  5734465d879d6814001ca466  Hunting  ...        646  the Hadza of Tanzania
#  87003  5735e8736c16ec1900b9288a  Hunting  ...        646      Hadza of Tanzania
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end        answer_text
#  87018  573447e5879d6814001ca479  Hunting  ...        475  marginal climates
#  87020  5735ec17012e2f140011a0dd  Hunting  ...        475  marginal climates
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end      answer_text
#  87032  573449b1acc1501500babd99  Hunting  ...         49  the upper class
#  87036  573449b1879d6814001ca491  Hunting  ...         49  the upper class
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end    answer_text
#  87033  573449b1acc1501500babd9a  Hunting  ...        180  food and furs
#  87038  573449b1879d6814001ca492  Hunting  ...        180  food and furs
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end answer_text
#  87034  573449b1acc1501500babd9b  Hunting  ...        379  Robin Hood
#  87039  573449b1879d6814001ca493  Hunting  ...        379  Robin Hood
#
#  [2 rows x 7 columns],
#                               id  ...                 answer_text
#  87035  573449b1acc1501500babd9c  ...  they "hunt the King's deer
#  87040  573449b1879d6814001ca494  ...  they "hunt the King's deer
#
#  [2 rows x 7 columns],
#                               id  ...                        answer_text
#  87037  573449b1acc1501500babd9d  ...  democratically in hunting for all
#  87041  573449b1879d6814001ca495  ...  democratically in hunting for all
#
#  [2 rows x 7 columns],
#                               id    title  ... answer_end       answer_text
#  87153  57345181879d6814001ca509  Hunting  ...        267  just six percent
#  87157  573610e9012e2f140011a18a  Hunting  ...        267       six percent
#
#  [2 rows x 7 columns]]

# %%
dupl = []
for dup in duplicated:
    if len(dup['context'].unique()) < len(dup):
        dupl.append(dup)

# %%
dupl
# Out:
#                             id            title  ... answer_end     answer_text
# 1791  56cfdb3e234ae51400d9bf7f  Frédéric_Chopin  ...       1182  Marie d'Agoult
# 1794  56d3227259d6e41400146280  Frédéric_Chopin  ...       1182  Marie d'Agoult
#
# [2 rows x 7 columns]

# %%
dd = []
for d in dupl:
    if len(d) > 2:
        dd.append(d)

# %%
duplicated_rows = []
for index, row in df[df.duplicated(['answer_text'])].iterrows():
    if len(df[df['answer_text'] == row['answer_text']])>1:
        duplicated_rows.append(row)
